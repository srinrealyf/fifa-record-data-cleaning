# %% [markdown]
# # Importing libraries

# %%
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Uploading the Dataset

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-cb3c0c8d-5c5e-430e-b1e0-1c888a05c273" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cb3c0c8d-5c5e-430e-b1e0-1c888a05c273">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
fifa_ds = pd.read_csv("fifa21 raw data v2.csv")
# Out:
# <ipython-input-3-d26579cd2aca>:1: DtypeWarning: Columns (76) have mixed types. Specify dtype option on import or set low_memory=False.
#   fifa_ds = pd.read_csv("fifa21 raw data v2.csv")

# %% [markdown]
# ## Understanding the Data

# %%
fifa_ds
# Out:
#            ID               Name                      LongName  \
# 0      158023           L. Messi                  Lionel Messi
# 1       20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro
# 2      200389           J. Oblak                     Jan Oblak
# 3      192985       K. De Bruyne               Kevin De Bruyne
# 4      190871          Neymar Jr    Neymar da Silva Santos Jr.
# ...       ...                ...                           ...
# 18974  247223             Xia Ao                        Ao Xia
# 18975  258760           B. Hough                     Ben Hough
# 18976  252757        R. McKinley                Ronan McKinley
# 18977  243790       Wang Zhen'ao                  Zhen'ao Wang
# 18978  252520          Zhou Xiao                     Xiao Zhou
#
#                                                photoUrl  \
# 0      https://cdn.sofifa.com/players/158/023/21_60.png
# 1      https://cdn.sofifa.com/players/020/801/21_60.png
# ...

# %%
fifa_ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18979 entries, 0 to 18978
# Data columns (total 77 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                18979 non-null  int64
#  1   Name              18979 non-null  object
#  2   LongName          18979 non-null  object
#  3   photoUrl          18979 non-null  object
#  4   playerUrl         18979 non-null  object
#  5   Nationality       18979 non-null  object
#  6   Age               18979 non-null  int64
#  7   ↓OVA              18979 non-null  int64
#  8   POT               18979 non-null  int64
#  9   Club              18979 non-null  object
#  10  Contract          18979 non-null  object
#  11  Positions         18979 non-null  object
#  12  Height            18979 non-null  object
#  13  Weight            18979 non-null  object
#  14  Preferred Foot    18979 non-null  object
#  15  BOV               18979 non-null  int64
# ...

# %%
fifa_ds.describe()
# Out:
#                   ID           Age          ↓OVA           POT           BOV  \
# count   18979.000000  18979.000000  18979.000000  18979.000000  18979.000000
# mean   226403.384794     25.194109     65.718636     71.136414     66.751726
# std     27141.054157      4.710520      6.968999      6.114635      6.747193
# min        41.000000     16.000000     47.000000     47.000000     48.000000
# 25%    210135.000000     21.000000     61.000000     67.000000     62.000000
# 50%    232418.000000     25.000000     66.000000     71.000000     67.000000
# 75%    246922.500000     29.000000     70.000000     75.000000     71.000000
# max    259216.000000     53.000000     93.000000     95.000000     93.000000
#
#           Attacking      Crossing     Finishing  Heading Accuracy  \
# count  18979.000000  18979.000000  18979.000000      18979.000000
# mean     248.938142     49.688392     45.842405         51.942726
# std       74.299428     18.131153     19.567081         17.294409
# ...

# %%
fifa_ds.shape
# Out:
# (18979, 77)

# %%
fifa_ds.Age.unique()
# Out:
# array([33, 35, 27, 29, 28, 31, 21, 34, 32, 25, 26, 30, 20, 24, 22, 23, 19,
#        38, 42, 36, 37, 18, 17, 39, 40, 41, 16, 43, 53])

# %%
fifa_ds.Height.unique()
# Out:
# array(['170cm', '187cm', '188cm', '181cm', '175cm', '184cm', '191cm',
#        '178cm', '193cm', '185cm', '199cm', '173cm', '168cm', '176cm',
#        '177cm', '183cm', '180cm', '189cm', '179cm', '195cm', '172cm',
#        '182cm', '186cm', '192cm', '165cm', '194cm', '167cm', '196cm',
#        '163cm', '190cm', '174cm', '169cm', '171cm', '197cm', '200cm',
#        '166cm', '6\'2"', '164cm', '198cm', '6\'3"', '6\'5"', '5\'11"',
#        '6\'4"', '6\'1"', '6\'0"', '5\'10"', '5\'9"', '5\'6"', '5\'7"',
#        '5\'4"', '201cm', '158cm', '162cm', '161cm', '160cm', '203cm',
#        '157cm', '156cm', '202cm', '159cm', '206cm', '155cm'], dtype=object)

# %%
fifa_ds.Nationality.unique()
# Out:
# array(['Argentina', 'Portugal', 'Slovenia', 'Belgium', 'Brazil', 'Poland',
#        'Egypt', 'France', 'Germany', 'Netherlands', 'Senegal', 'Spain',
#        'England', 'Scotland', 'Korea Republic', 'Costa Rica', 'Italy',
#        'Gabon', 'Croatia', 'Uruguay', 'Switzerland', 'Serbia', 'Slovakia',
#        'Morocco', 'Algeria', 'Denmark', 'Hungary', 'Bosnia Herzegovina',
#        'Nigeria', 'Cameroon', 'Norway', 'Ghana', 'Mexico', 'Austria',
#        'Albania', 'Colombia', 'Chile', 'Ivory Coast', 'Greece', 'Finland',
#        'Wales', 'Sweden', 'Togo', 'Czech Republic', 'Russia', 'Venezuela',
#        'Canada', 'United States', 'Guinea', 'Montenegro', 'Israel',
#        'Republic of Ireland', 'Ukraine', 'Turkey', 'Ecuador', 'Jamaica',
#        'DR Congo', 'Australia', 'China PR', 'Armenia', 'Northern Ireland',
#        'North Macedonia', 'Kosovo', 'Mali', 'Peru',
#        'Central African Republic', 'Iceland', 'Burkina Faso', 'Paraguay',
# ...

# %%
fifa_ds.Positions.unique()
# Out:
# array(['RW, ST, CF', 'ST, LW', 'GK', 'CAM, CM', 'LW, CAM', 'ST', 'RW',
#        'ST, LW, RW', 'CB', 'LW', 'CDM', 'CF, ST', 'LW, RW', 'CDM, CM',
#        'CDM, RB', 'CF, CAM', 'LW, ST', 'CM', 'ST, CF, LW', 'RM, LM, CAM',
#        'RB', 'RW, CAM, CM', 'LB', 'LM, CF', 'CF', 'RW, LW', 'CAM, RM, RW',
#        'CM, CDM', 'CAM, CF, ST', 'CM, CDM, CAM', 'CF, LW, CAM',
#        'CAM, RM, CF', 'LM, ST', 'RM, LM, RW', 'LM', 'CAM, RW', 'CB, CDM',
#        'RW, RM', 'LW, CF', 'CM, RM, LM', 'LB, LM', 'CAM, CM, RM',
#        'CAM, CM, CF', 'CAM, CF', 'LM, RM, LW', 'LM, LB, CM', 'CM, LM, LB',
#        'RM, RW', 'RM, CM', 'CAM, CM, LW', 'CB, LB', 'RM, RB', 'ST, RW',
#        'LM, RW, LW', 'RB, LB', 'RB, RM', 'RM', 'LM, RM, CF', 'CAM, RM',
#        'RB, RWB', 'CDM, CB, CM', 'CAM, RM, ST', 'LM, LW, RM', 'CM, CAM',
#        'ST, RM, CF', 'LM, RM', 'RM, CF', 'LM, LWB', 'RW, RM, CF',
#        'RB, CM', 'LW, CAM, RW', 'CAM, LW, CM', 'CM, CAM, CDM',
# ...

# %% [markdown]
# ## Remove Duplicated Rows

# %%
fifa_ds.drop_duplicates
# Out:
# <bound method DataFrame.drop_duplicates of            ID               Name                      LongName  \
# 0      158023           L. Messi                  Lionel Messi
# 1       20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro
# 2      200389           J. Oblak                     Jan Oblak
# 3      192985       K. De Bruyne               Kevin De Bruyne
# 4      190871          Neymar Jr    Neymar da Silva Santos Jr.
# ...       ...                ...                           ...
# 18974  247223             Xia Ao                        Ao Xia
# 18975  258760           B. Hough                     Ben Hough
# 18976  252757        R. McKinley                Ronan McKinley
# 18977  243790       Wang Zhen'ao                  Zhen'ao Wang
# 18978  252520          Zhou Xiao                     Xiao Zhou
#
#                                                photoUrl  \
# 0      https://cdn.sofifa.com/players/158/023/21_60.png
# ...

# %%
fifa_ds.shape
# Out:
# (18979, 77)

# %%
fifa_ds.head()
# Out:
#        ID               Name                      LongName  \
# 0  158023           L. Messi                  Lionel Messi
# 1   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro
# 2  200389           J. Oblak                     Jan Oblak
# 3  192985       K. De Bruyne               Kevin De Bruyne
# 4  190871          Neymar Jr    Neymar da Silva Santos Jr.
#
#                                            photoUrl  \
# 0  https://cdn.sofifa.com/players/158/023/21_60.png
# 1  https://cdn.sofifa.com/players/020/801/21_60.png
# 2  https://cdn.sofifa.com/players/200/389/21_60.png
# 3  https://cdn.sofifa.com/players/192/985/21_60.png
# 4  https://cdn.sofifa.com/players/190/871/21_60.png
#
#                                            playerUrl Nationality  Age  ↓OVA  \
# 0  http://sofifa.com/player/158023/lionel-messi/2...   Argentina   33    93
# 1  http://sofifa.com/player/20801/c-ronaldo-dos-s...    Portugal   35    92
# ...

# %% [markdown]
# Display all 77 columns in the dataset

# %%
pd.set_option('display.max_columns',None)

# %%
fifa_ds.drop(columns=['photoUrl','playerUrl'], inplace=True)

# %%
fifa_ds.head()
# Out:
#        ID               Name                      LongName Nationality  Age  \
# 0  158023           L. Messi                  Lionel Messi   Argentina   33
# 1   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro    Portugal   35
# 2  200389           J. Oblak                     Jan Oblak    Slovenia   27
# 3  192985       K. De Bruyne               Kevin De Bruyne     Belgium   29
# 4  190871          Neymar Jr    Neymar da Silva Santos Jr.      Brazil   28
#
#    ↓OVA  POT                         Club     Contract   Positions Height  \
# 0    93   93         \n\n\n\nFC Barcelona  2004 ~ 2021  RW, ST, CF  170cm
# 1    92   92             \n\n\n\nJuventus  2018 ~ 2022      ST, LW  187cm
# 2    91   93      \n\n\n\nAtlético Madrid  2014 ~ 2023          GK  188cm
# 3    91   91      \n\n\n\nManchester City  2015 ~ 2023     CAM, CM  181cm
# 4    91   91  \n\n\n\nParis Saint-Germain  2017 ~ 2022     LW, CAM  175cm
#
# ...

# %% [markdown]
# Convert Joined (object) to Joined (datetime)

# %%
fifa_ds['Joined'] = pd.to_datetime(fifa_ds['Joined'])

# %%
def check_date(element):
    if isinstance(element, (pd.Timestamp, pd.datetime)):
        return 'Valid Date'
    elif callable(element):  # Check if the element is a function
        return 'Function Object'
    else:
        return 'Invalid'

# Apply the custom function to the 'Joined' column
result = fifa_ds['Joined'].apply(check_date)

# Print the result
print(result)
# Out:
# 0        Valid Date
# 1        Valid Date
# 2        Valid Date
# 3        Valid Date
# 4        Valid Date
#             ...
# 18974    Valid Date
# 18975    Valid Date
# 18976    Valid Date
# 18977    Valid Date
# 18978    Valid Date
# Name: Joined, Length: 18979, dtype: object
# <ipython-input-16-63a0faa4820c>:2: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   if isinstance(element, (pd.Timestamp, pd.datetime)):

# %%
fifa_ds.head()
# Out:
#        ID               Name                      LongName Nationality  Age  \
# 0  158023           L. Messi                  Lionel Messi   Argentina   33
# 1   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro    Portugal   35
# 2  200389           J. Oblak                     Jan Oblak    Slovenia   27
# 3  192985       K. De Bruyne               Kevin De Bruyne     Belgium   29
# 4  190871          Neymar Jr    Neymar da Silva Santos Jr.      Brazil   28
#
#    ↓OVA  POT                         Club     Contract   Positions Height  \
# 0    93   93         \n\n\n\nFC Barcelona  2004 ~ 2021  RW, ST, CF  170cm
# 1    92   92             \n\n\n\nJuventus  2018 ~ 2022      ST, LW  187cm
# 2    91   93      \n\n\n\nAtlético Madrid  2014 ~ 2023          GK  188cm
# 3    91   91      \n\n\n\nManchester City  2015 ~ 2023     CAM, CM  181cm
# 4    91   91  \n\n\n\nParis Saint-Germain  2017 ~ 2022     LW, CAM  175cm
#
# ...

# %%
fifa_ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18979 entries, 0 to 18978
# Data columns (total 75 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                18979 non-null  int64
#  1   Name              18979 non-null  object
#  2   LongName          18979 non-null  object
#  3   Nationality       18979 non-null  object
#  4   Age               18979 non-null  int64
#  5   ↓OVA              18979 non-null  int64
#  6   POT               18979 non-null  int64
#  7   Club              18979 non-null  object
#  8   Contract          18979 non-null  object
#  9   Positions         18979 non-null  object
#  10  Height            18979 non-null  object
#  11  Weight            18979 non-null  object
#  12  Preferred Foot    18979 non-null  object
#  13  BOV               18979 non-null  int64
#  14  Best Position     18979 non-null  object
#  15  Joined            18979 non-null  datetime64[ns]
# ...

# %%
fifa_ds
# Out:
#            ID               Name                      LongName Nationality  \
# 0      158023           L. Messi                  Lionel Messi   Argentina
# 1       20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro    Portugal
# 2      200389           J. Oblak                     Jan Oblak    Slovenia
# 3      192985       K. De Bruyne               Kevin De Bruyne     Belgium
# 4      190871          Neymar Jr    Neymar da Silva Santos Jr.      Brazil
# ...       ...                ...                           ...         ...
# 18974  247223             Xia Ao                        Ao Xia    China PR
# 18975  258760           B. Hough                     Ben Hough     England
# 18976  252757        R. McKinley                Ronan McKinley     England
# 18977  243790       Wang Zhen'ao                  Zhen'ao Wang    China PR
# 18978  252520          Zhou Xiao                     Xiao Zhou    China PR
#
# ...

# %% [markdown]
# Removing \n\n\n\n prefix from name of the clubs

# %%
def cleaning(val):
  if isinstance(val,str):
    if val.find('\n')!=-1:
      return val.removeprefix('\n\n\n\n')
    else:
      return val
  else:
    return val

# %%
fifa_ds['Club']=fifa_ds['Club'].apply(cleaning)

# %%
fifa_ds
# Out:
#            ID               Name                      LongName Nationality  \
# 0      158023           L. Messi                  Lionel Messi   Argentina
# 1       20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro    Portugal
# 2      200389           J. Oblak                     Jan Oblak    Slovenia
# 3      192985       K. De Bruyne               Kevin De Bruyne     Belgium
# 4      190871          Neymar Jr    Neymar da Silva Santos Jr.      Brazil
# ...       ...                ...                           ...         ...
# 18974  247223             Xia Ao                        Ao Xia    China PR
# 18975  258760           B. Hough                     Ben Hough     England
# 18976  252757        R. McKinley                Ronan McKinley     England
# 18977  243790       Wang Zhen'ao                  Zhen'ao Wang    China PR
# 18978  252520          Zhou Xiao                     Xiao Zhou    China PR
#
# ...

# %% [markdown]
# Split Joined column to Individual Day, Month, Year

# %%
fifa_ds['Day'] = fifa_ds['Joined'].dt.day
fifa_ds['Month'] = fifa_ds['Joined'].dt.month
fifa_ds['Year'] = fifa_ds['Joined'].dt.year

# %%
fifa_ds
# Out:
#            ID               Name                      LongName Nationality  \
# 0      158023           L. Messi                  Lionel Messi   Argentina
# 1       20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro    Portugal
# 2      200389           J. Oblak                     Jan Oblak    Slovenia
# 3      192985       K. De Bruyne               Kevin De Bruyne     Belgium
# 4      190871          Neymar Jr    Neymar da Silva Santos Jr.      Brazil
# ...       ...                ...                           ...         ...
# 18974  247223             Xia Ao                        Ao Xia    China PR
# 18975  258760           B. Hough                     Ben Hough     England
# 18976  252757        R. McKinley                Ronan McKinley     England
# 18977  243790       Wang Zhen'ao                  Zhen'ao Wang    China PR
# 18978  252520          Zhou Xiao                     Xiao Zhou    China PR
#
# ...

# %% [markdown]
# List name of all columns

# %%
fifa_ds.columns.tolist()
# Out:
# ['ID',
#  'Name',
#  'LongName',
#  'Nationality',
#  'Age',
#  '↓OVA',
#  'POT',
#  'Club',
#  'Contract',
#  'Positions',
#  'Height',
#  'Weight',
#  'Preferred Foot',
#  'BOV',
#  'Best Position',
#  'Joined',
#  'Loan Date End',
#  'Value',
#  'Wage',
#  'Release Clause',
#  'Attacking',
#  'Crossing',
#  'Finishing',
#  'Heading Accuracy',
#  'Short Passing',
#  'Volleys',
#  'Skill',
#  'Dribbling',
#  'Curve',
#  'FK Accuracy',
#  'Long Passing',
#  'Ball Control',
#  'Movement',
#  'Acceleration',
#  'Sprint Speed',
#  'Agility',
#  'Reactions',
#  'Balance',
#  'Power',
#  'Shot Power',
#  'Jumping',
#  'Stamina',
#  'Strength',
#  'Long Shots',
#  'Mentality',
#  'Aggression',
#  'Interceptions',
#  'Positioning',
#  'Vision',
#  'Penalties',
#  'Composure',
#  'Defending',
#  'Marking',
#  'Standing Tackle',
#  'Sliding Tackle',
#  'Goalkeeping',
#  'GK Diving',
#  'GK Handling',
#  'GK Kicking',
#  'GK Positioning',
#  'GK Reflexes',
#  'Total Stats',
#  'Base Stats',
# ...

# %% [markdown]
# Reorder the columns

# %%
reordered_columns = ['ID','Name','LongName','Nationality','Age','↓OVA','POT','Club','Contract','Positions','Height','Weight','Preferred Foot',
           'BOV','Best Position','Joined','Day','Month','Year','Loan Date End','Value','Wage','Release Clause','Attacking','Crossing','Finishing','Heading Accuracy',
           'Short Passing','Volleys','Skill','Dribbling','Curve','FK Accuracy','Long Passing','Ball Control','Movement','Acceleration','Sprint Speed',
           'Agility','Reactions','Balance','Power','Shot Power','Jumping','Stamina','Strength','Long Shots','Mentality','Aggression','Interceptions',
           'Positioning','Vision','Penalties','Composure','Defending','Marking','Standing Tackle','Sliding Tackle','Goalkeeping','GK Diving','GK Handling',
           'GK Kicking','GK Positioning','GK Reflexes','Total Stats','Base Stats','W/F','SM','A/W','D/W','IR','PAC','SHO','PAS','DRI','DEF','PHY','Hits']

# %%
fifa_updated = fifa_ds[reordered_columns]

# %%
fifa_updated
# Out:
#            ID               Name                      LongName Nationality  \
# 0      158023           L. Messi                  Lionel Messi   Argentina
# 1       20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro    Portugal
# 2      200389           J. Oblak                     Jan Oblak    Slovenia
# 3      192985       K. De Bruyne               Kevin De Bruyne     Belgium
# 4      190871          Neymar Jr    Neymar da Silva Santos Jr.      Brazil
# ...       ...                ...                           ...         ...
# 18974  247223             Xia Ao                        Ao Xia    China PR
# 18975  258760           B. Hough                     Ben Hough     England
# 18976  252757        R. McKinley                Ronan McKinley     England
# 18977  243790       Wang Zhen'ao                  Zhen'ao Wang    China PR
# 18978  252520          Zhou Xiao                     Xiao Zhou    China PR
#
# ...

# %% [markdown]
# Remove unnecessary characters such as 'cm', 'kg', 'lbs', 'K'
# and convert the metrics to float with the conversion values

# %%
def obj_to_float(val):
    if isinstance(val, str):
        if val.find('cm')!=-1:
            val = val.replace('cm', '')
            return float(val)
        elif val.find("'")!=-1:
            val = val.split("\'")
            h = float(val[0])*(30.48) + float(val[1].replace('"', ''))*(2.54)
            return h
        elif val.find('kg')!=-1:
            val = val.replace('kg', '')
            return float(val)
        elif val.find('lbs')!=-1:
            val = val.replace('lbs', '')
            return float(val)*0.45359237
        elif val.find('K')!= -1:
            val = val.replace('K', '')
            return float(val)*1000
        else:
            return float(val)
    else:
        return val

# %%
fifa_updated['Height']=fifa_updated['Height'].apply(obj_to_float)
fifa_updated['Weight']=fifa_updated['Weight'].apply(obj_to_float)
fifa_updated['Hits']=fifa_updated['Hits'].apply(obj_to_float)

# %%
fifa_updated[['Height','Weight','Hits']]
# Out:
#        Height  Weight   Hits
# 0       170.0    72.0  771.0
# 1       187.0    83.0  562.0
# 2       188.0    87.0  150.0
# 3       181.0    70.0  207.0
# 4       175.0    68.0  595.0
# ...       ...     ...    ...
# 18974   178.0    66.0    NaN
# 18975   175.0    65.0    NaN
# 18976   179.0    74.0    NaN
# 18977   175.0    69.0    NaN
# 18978   188.0    75.0    NaN
#
# [18979 rows x 3 columns]

# %% [markdown]
# Rename the column

# %%
fifa_updated.rename(columns = {'↓OVA':'OVA'},inplace=True)

# %%
fifa_updated.head()
# Out:
#        ID               Name                      LongName Nationality  Age  \
# 0  158023           L. Messi                  Lionel Messi   Argentina   33
# 1   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro    Portugal   35
# 2  200389           J. Oblak                     Jan Oblak    Slovenia   27
# 3  192985       K. De Bruyne               Kevin De Bruyne     Belgium   29
# 4  190871          Neymar Jr    Neymar da Silva Santos Jr.      Brazil   28
#
#    OVA  POT                 Club     Contract   Positions  Height  Weight  \
# 0   93   93         FC Barcelona  2004 ~ 2021  RW, ST, CF   170.0    72.0
# 1   92   92             Juventus  2018 ~ 2022      ST, LW   187.0    83.0
# 2   91   93      Atlético Madrid  2014 ~ 2023          GK   188.0    87.0
# 3   91   91      Manchester City  2015 ~ 2023     CAM, CM   181.0    70.0
# 4   91   91  Paris Saint-Germain  2017 ~ 2022     LW, CAM   175.0    68.0
#
# ...

# %% [markdown]
# Remove unnecessary characters such as 'K', 'M', '€'
# and convert the metrics to float with the INR conversion rates

# %%
def money(val):
    if isinstance(val, str):
        if val.find('K')!=-1:
            return float(val.replace('K', '').replace('€', ''))*1000*90.57
        elif val.find('M')!=-1:
            return float(val.replace('M', '').replace('€', ''))*10e6
        elif val.find('€')!=-1:
            return float(val.replace('€', ''))
        else:
            return val
    else:
        return val

# %%
fifa_updated['Value'] = fifa_updated['Value'].apply(money)
fifa_updated['Release Clause'] = fifa_updated['Release Clause'].apply(money)
fifa_updated['Wage'] = fifa_updated['Wage'].apply(money)

# %%
fifa_updated.head()
# Out:
#        ID               Name                      LongName Nationality  Age  \
# 0  158023           L. Messi                  Lionel Messi   Argentina   33
# 1   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro    Portugal   35
# 2  200389           J. Oblak                     Jan Oblak    Slovenia   27
# 3  192985       K. De Bruyne               Kevin De Bruyne     Belgium   29
# 4  190871          Neymar Jr    Neymar da Silva Santos Jr.      Brazil   28
#
#    OVA  POT                 Club     Contract   Positions  Height  Weight  \
# 0   93   93         FC Barcelona  2004 ~ 2021  RW, ST, CF   170.0    72.0
# 1   92   92             Juventus  2018 ~ 2022      ST, LW   187.0    83.0
# 2   91   93      Atlético Madrid  2014 ~ 2023          GK   188.0    87.0
# 3   91   91      Manchester City  2015 ~ 2023     CAM, CM   181.0    70.0
# 4   91   91  Paris Saint-Germain  2017 ~ 2022     LW, CAM   175.0    68.0
#
# ...

# %%
fifa_updated.loc[fifa_updated['Best Position']=='RW']
# Out:
#            ID            Name                        LongName     Nationality  \
# 0      158023        L. Messi                    Lionel Messi       Argentina
# 6      209331        M. Salah                   Mohamed Salah           Egypt
# 31     218667  Bernardo Silva  Bernardo Mota Carvalho e Silva        Portugal
# 43     183898     A. Di María                  Ángel Di María       Argentina
# 75     204485       R. Mahrez                    Riyad Mahrez         Algeria
# ...       ...             ...                             ...             ...
# 18477  252142     M. Petratos                   Maki Petratos       Australia
# 18555  258508      E. Nnamani                   Emeka Nnamani         Denmark
# 18828  256458       K. Swaleh               Kent Malic Swaleh          Norway
# 18852  252650   Lee Seung Jae                   Seung Jae Lee  Korea Republic
# 18917  255618       Gao Xiang                       Xiang Gao        China PR
#
# ...

# %%
fifa_updated
# Out:
#            ID               Name                      LongName Nationality  \
# 0      158023           L. Messi                  Lionel Messi   Argentina
# 1       20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro    Portugal
# 2      200389           J. Oblak                     Jan Oblak    Slovenia
# 3      192985       K. De Bruyne               Kevin De Bruyne     Belgium
# 4      190871          Neymar Jr    Neymar da Silva Santos Jr.      Brazil
# ...       ...                ...                           ...         ...
# 18974  247223             Xia Ao                        Ao Xia    China PR
# 18975  258760           B. Hough                     Ben Hough     England
# 18976  252757        R. McKinley                Ronan McKinley     England
# 18977  243790       Wang Zhen'ao                  Zhen'ao Wang    China PR
# 18978  252520          Zhou Xiao                     Xiao Zhou    China PR
#
# ...

# %%
fifa_updated
# Out:
#            ID               Name                      LongName Nationality  \
# 0      158023           L. Messi                  Lionel Messi   Argentina
# 1       20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro    Portugal
# 2      200389           J. Oblak                     Jan Oblak    Slovenia
# 3      192985       K. De Bruyne               Kevin De Bruyne     Belgium
# 4      190871          Neymar Jr    Neymar da Silva Santos Jr.      Brazil
# ...       ...                ...                           ...         ...
# 18974  247223             Xia Ao                        Ao Xia    China PR
# 18975  258760           B. Hough                     Ben Hough     England
# 18976  252757        R. McKinley                Ronan McKinley     England
# 18977  243790       Wang Zhen'ao                  Zhen'ao Wang    China PR
# 18978  252520          Zhou Xiao                     Xiao Zhou    China PR
#
# ...

# %%
fifa_updated['OVA'].min()
# Out:
# 47

# %%
ova_freq = [fifa_updated.query(f'{i}<OVA <= {i+10}').shape[0] for i in range(40,100,10)]
ova_freq
# Out:
# [238, 3941, 10264, 4167, 363, 6]

# %%
plt.figure(figsize = (10,10))
plt.title("Overall Rating Analysis")
plt.hist(fifa_updated['OVA'], bins =[40,50,60,70,80,90,100], color = 'cyan', edgecolor = 'black')
plt.show()

# %%
plt.figure(figsize = (20,10))
plt.title("Overall Rating Range")
plt.pie(ova_freq, autopct='%.2f', labels = [f'{i} to {i+10}' for i in range(40,100,10)])
plt.show()

# %%
plt.figure(figsize = (10,10))
sns.histplot(fifa_updated['OVA'], bins =[40,50,60,70,80,90,100], edgecolor = 'black', kde = True)
plt.show()

# %%
ova_wage = [fifa_updated.query(f'{i}<OVA <= {i+10}')['Wage'].median() for i in range(40,100,10)]
ova_wage
# Out:
# [500.0, 90570.0, 271710.0, 1539690.0, 7426739.999999999, 23095350.0]

# %%
plt.bar([40,50,60,70,80,90], ova_wage, width = 10, align = 'edge', edgecolor = 'black')
plt.xticks(np.arange(40,101,10))
plt.show()

# %%
gk_df = fifa_updated[fifa_updated['Best Position']=='GK']
gk_df
# Out:
#            ID           Name               LongName          Nationality  Age  \
# 2      200389       J. Oblak              Jan Oblak             Slovenia   27
# 7      212831        Alisson  Alisson Ramses Becker               Brazil   27
# 9      192448  M. ter Stegen  Marc-André ter Stegen              Germany   28
# 13     192119    T. Courtois       Thibaut Courtois              Belgium   28
# 14     167495       M. Neuer           Manuel Neuer              Germany   34
# ...       ...            ...                    ...                  ...  ...
# 18938  255986    P. McGarvey       Patrick McGarvey  Republic of Ireland   16
# 18941  258664      J. Arthur            Jack Arthur              England   17
# 18951  183749      L. Walker          Laurie Walker              England   30
# 18955  250978        Ma Zhen                Zhen Ma             China PR   22
# 18964  256662    R. Fontalvo      Reinaldo Fontalvo             Colombia   21
#
# ...

# %%
gk_df.columns
# Out:
# Index(['ID', 'Name', 'LongName', 'Nationality', 'Age', 'OVA', 'POT', 'Club',
#        'Contract', 'Positions', 'Height', 'Weight', 'Preferred Foot', 'BOV',
#        'Best Position', 'Joined', 'Day', 'Month', 'Year', 'Loan Date End',
#        'Value', 'Wage', 'Release Clause', 'Attacking', 'Crossing', 'Finishing',
#        'Heading Accuracy', 'Short Passing', 'Volleys', 'Skill', 'Dribbling',
#        'Curve', 'FK Accuracy', 'Long Passing', 'Ball Control', 'Movement',
#        'Acceleration', 'Sprint Speed', 'Agility', 'Reactions', 'Balance',
#        'Power', 'Shot Power', 'Jumping', 'Stamina', 'Strength', 'Long Shots',
#        'Mentality', 'Aggression', 'Interceptions', 'Positioning', 'Vision',
#        'Penalties', 'Composure', 'Defending', 'Marking', 'Standing Tackle',
#        'Sliding Tackle', 'Goalkeeping', 'GK Diving', 'GK Handling',
#        'GK Kicking', 'GK Positioning', 'GK Reflexes', 'Total Stats',
# ...

# %%
gk_heat = gk_df[[#'ID', 'Name', 'LongName', 'Nationality', 'Age', 'OVA', 'POT', 'Club',
#        'Contract', 'Positions', 'Height', 'Weight', 'Preferred Foot', 'BOV',
#        'Best Position', 'Joined', 'Loan Date End', 'Value', 'Wage',
#        'Release Clause', 'Attacking', 'Crossing', 'Finishing',
#        'Heading Accuracy', 'Short Passing', 'Volleys', 'Skill', 'Dribbling',
#        'Curve', 'FK Accuracy', 'Long Passing','Ball Control', \
       'Movement',
#        'Acceleration', 'Sprint Speed', 'Agility', \
       'Reactions', 'Balance',
       'Power', 'Shot Power', \
#        'Jumping', 'Stamina', 'Strength', 'Long Shots',
       'Mentality', 'Aggression', \
#        'Interceptions', 'Positioning', 'Vision','Penalties', \
       'Composure',\
#        'Defending', 'Marking', 'Standing Tackle','Sliding Tackle',\
       'Goalkeeping', 'GK Diving', 'GK Handling',
       'GK Kicking', 'GK Positioning', 'GK Reflexes', \
#        'Total Stats',
#        'Base Stats', 'W/F', 'SM', 'A/W', 'D/W', 'IR', 'PAC', 'SHO', 'PAS',
#        'DRI', 'DEF', 'PHY', 'Hits'
      ]].dropna().corr()
gk_heat
# Out:
#                 Movement  Reactions   Balance     Power  Shot Power  \
# Movement        1.000000   0.675764  0.637230  0.737210    0.505933
# Reactions       0.675764   1.000000  0.200374  0.648893    0.651581
# Balance         0.637230   0.200374  1.000000  0.393056    0.140351
# Power           0.737210   0.648893  0.393056  1.000000    0.630243
# Shot Power      0.505933   0.651581  0.140351  0.630243    1.000000
# Mentality       0.593681   0.571390  0.291505  0.639892    0.519411
# Aggression      0.294110   0.301278  0.091973  0.368375    0.251476
# Composure       0.498916   0.540615  0.184638  0.508782    0.472601
# Goalkeeping     0.589423   0.806193  0.136188  0.678612    0.863978
# GK Diving       0.577614   0.777504  0.138639  0.637330    0.746407
# GK Handling     0.520020   0.744312  0.099885  0.605413    0.764539
# GK Kicking      0.506540   0.652297  0.140930  0.631094    0.998786
# GK Positioning  0.548102   0.775559  0.120492  0.632976    0.763668
# ...

# %%
plt.figure(figsize = (10,10))
plt.title('Goal Keeper Stats')
sns.set_palette("RdBu")
sns.heatmap(gk_heat,annot=True, cbar = True, cmap = 'RdBu')
# Out:
# <Axes: title={'center': 'Goal Keeper Stats'}>
